# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyash-1908/Davis_Training/blob/main/Code/classwork/SimpleInterest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to calculate Simple Interest
def calculate_si(p, r, t):
    # Formula: SI = (P * R * T) / 100
    return (p * r * t) / 100


# Taking input from user
p = float(input("Enter Principal: "))
r = float(input("Enter Rate: "))
t = float(input("Enter Time: "))

# Calling function
si = calculate_si(p, r, t)

# Display result
print("Simple Interest =", si)

# %%
# Function to check odd or even

def check_number(n):
    if n % 2 == 0:
        return "Even"
    else:
        return "Odd"

# Taking input
num = int(input("Enter a number: "))

# Calling function
result = check_number(num)

# Display result
print("The number is", result)
